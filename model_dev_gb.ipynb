# %%
# Imports
import pandas as pd
import pickle
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import Pipeline

# %%
# Load preprocessed data splits for Random Forest, Gradient Boosting (for df_1 and df_2)
with open('rf_gb_splits_df1.pkl', 'rb') as f:
    X_train_1, X_test_1, y_train_1, y_test_1 = pickle.load(f)

with open('rf_gb_splits_df2.pkl', 'rb') as f:
    X_train_2, X_test_2, y_train_2, y_test_2 = pickle.load(f)

# %%
# Creating pipeline for Gradient Boosting Regressor
model_pipeline = Pipeline(steps=[('regressor', GradientBoostingRegressor())])

# %%
# Training model on df_1
model_pipeline.fit(X_train_1, y_train_1)
# Out:
# Pipeline(steps=[('regressor', GradientBoostingRegressor())])

# %%
# Making predictions on df_1
y_pred_1 = model_pipeline.predict(X_test_1)

# %%
# Evaluating model on df_1
mse_1 = mean_squared_error(y_test_1, y_pred_1)
r2_1 = r2_score(y_test_1, y_pred_1)

# %%
# Displaying evaluation metrics for df_1
print("df_1 Gradient Boosting Regressor Test Results")
print(f'MSE: {mse_1}, R2: {r2_1}')
print("="*60)
# Out:
# df_1 Gradient Boosting Regressor Test Results
# MSE: 32289415.872093033, R2: -8.228689379086163e-05
# ...

# %%
# Training model on df_2
model_pipeline.fit(X_train_2, y_train_2)
# Out:
# Pipeline(steps=[('regressor', GradientBoostingRegressor())])

# %%
# Making predictions on df_2
y_pred_2 = model_pipeline.predict(X_test_2)

# %%
# Evaluating model on df_2
mse_2 = mean_squared_error(y_test_2, y_pred_2)
r2_2 = r2_score(y_test_2, y_pred_2)

# %%
# Printing evaluation metrics for df_2
print("df_2 Gradient Boosting Regressor Test Results")
print(f'MSE: {mse_2}, R2: {r2_2}')
print("="*60)
# Out:
# df_2 Gradient Boosting Regressor Test Results
# MSE: 2328211795.214079, R2: -0.00041694900874023055
# ...
